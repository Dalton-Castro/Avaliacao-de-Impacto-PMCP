# %% [markdown]
# ***
# <h1 style='color: Darkblue; font-size: 36px; font-weight: bold;'>DESCRIÇÃO DO PROJETO</h1>
#
# ***
# <h1 style='color: Darkblue; font-size: 25px; font-weight: bold;'>Condições Iniciais e Resultados Futuros:</h1>
#
# <h1 style='color: Darkblue; font-size: 25px; font-weight: bold;'>Uma Avaliação de Impacto do Programa Mãe Coruja Pernambucana (PMCP) Sobre o Desempenho Escolar das Crianças</h1>
#
# ***
# <h1 style='color: Darkblue; font-size: 18px; font-weight: bold;'>Neste projeto, tentaremos capturar o efeito causal do Programa Mãe Coruja Pernambucana sobre o desempenho escolar das crianças afetadas, com base nas proficiências médias das escolas divulgadas pelo Sistema de Avaliação Educacional de Pernambuco (SAEPE)</h1>
#
# ***

# %% [markdown]
# # <font color='darkblue'>PROGRAMA MÃE CORUJA PERNAMBUCANA (PMCP) </font>
# <hr style='border: 2px solid darkblue;'>

# %% [markdown]
# ### Implementado em 2008, no estado de Pernambuco, o Programa Mãe Coruja Pernambucana tinha como objetivo reduzir os altos índices de mortalidade infantil e materna no estado de Pernambuco.
#
# ### O PMCP atua por meio de uma extensa rede de ações calcadas em assistências no pré-natal, acompanhamento das crianças e auxílio durante a primeira infância, das quais o amparo ao período gestacional da mulher se destaca como o seu maior enfoque.
#
# ### Implementação:
#
# ***
# #### A escolha da região e dos municípios por onde o programa começaria a ser implantado obedeceu a alguns critérios, sendo levada, ainda, em consideração as onze Gerências Regionais de Saúde (Geres) responsáveis pelos 185 municípios do estado.
#
# #### Os principais critérios utilizados foram a taxa de mortalidade infantil, os Índice de Desenvolvimento Humano (IDH) e Índice de Desenvolvimento Infantil (IDI). Seriam considerados aqueles municípios que possuíssem uma taxa de mortalidade infantil maior ou igual a 25 óbitos a cada mil nascidos vivos e que apresentassem baixos IDH e IDI. Além disso, determinou-se que o programa seria implantado em todos os municípios das Geres para os casos em que ao menos 50\% dos municípios nela situados  detivessem uma taxa de mortalidade infantil superior a 25 óbitos por mil nascidos vivos.
#
#
# #### Com base nesses parâmetros, a implementação iniciou-se pela microregião de Araripina (Sertão do Araripe), seguida pelo Sertão do Moxotó (VI Geres). Desse modo, 24 municípios foram contemplados pelo PMCP em sua primeira fase de implementação. Ao longo dos anos o programa se ampliou de forma a atuar, atualmente, em 105 dos 185 municípios do estado.
#
# #### A seguinte tabela fornece os anos de participação de cada município de Pernambuco no programa:
#
# ***

# %%
pd.read_excel('Dados/tabela_de_participacao.xls', index_col=0)
# Out:
#      Códigos dos Municípios  \
# 0                   2600054
# 1                   2600104
# 2                   2600203
# 3                   2600302
# 4                   2600401
# ..                      ...
# 180                 2616183
# 181                 2616209
# 182                 2616308
# 183                 2616407
# 184                 2616506
#
#     Participação dos Municípios no Programa Mãe Coruja Pernambucana ao longo do período de 2007 a 2014  \
# 0                                         Abreu e Lima
# 1                                Afogados da Ingazeira
# 2                                              Afrânio
# 3                                            Agrestina
# 4                                           Água Preta
# ..                                                 ...
# 180                                  Vertente do Lério
# 181                                          Vertentes
# 182                                           Vicência
# ...

# %% [markdown]
# ### Ações Específicas do Programa:
# ***
# <ul style='font-size: 14px; line-height: 2; text-align: justify;'>
#     <li><b>círculos de educação e cultura</b></li>
#     <li><b>cursos de qualificação profissional para as mães</b></li>
#     <li><b>oficinas de segurança alimentar e nutricional</b></li>
#     <li><b>inclusão em programas sociais nos Centros Regionais de Assistência Social</b></li>
#     <li><b>fornecimento de kits do bebê para as gestantes</b></li>
#     <li><b>assistência ao pré-natal (com a realização de sete ou mais consultas)</b></li>
#     <li><b>assistência ao parto e ao puerpério</b></li>
#     <li><b>reorganização da rede de atenção ao parto</b></li>
#     <li><b>incentivo ao aleitamento materno</b></li>
#     <li><b>acompanhamento e incentivo da vacinação da criança</b></li>
#     <li><b>acesso ao registro de nascimento</b></li>
#     <li><b>acompanhamento do crescimento e do desenvolvimento da criança</b></li>
# </ul>
#
# ***
#
# ### Fontes:
#
# https://maecoruja.pe.gov.br/o-programa/
#
# http://portal.saude.pe.gov.br/programa/secretaria-executiva-de-atencao-saude/programa-mae-coruja-pernambucana
#
# Livro Mãe Coruja Pernambucana (os 4 volumes), contidos em: https://maecoruja.pe.gov.br/leituras-importantes/
#
# ***
#
#
#
# ### Essas ações desempenhadas pelo PMCP refletem impactos exógenos em uma série de variáveis que podem afetar os resultados futuros das crianças, como a qualidade do pré-natal e da primeira infância, além da qualidade nutricional e o grau de instrução dos pais, sendo expressos, por exemplo, através dos resultados escolares.
#
# ***
#
# ### Referências:
#
# ALMOND, D.; MAZUMDER, B.; EWIJK, R. V. In utero ramadan exposure and children’sacademic performance. The Economic Journal, Oxford University Press Oxford, UK, v. 125,n. 589, p. 1501–1533, 2014.
#
# BROWNELL, M. D. et al. A population-based analysis of factors that predict early language andcognitive development.Early Childhood Research Quarterly, Elsevier, v. 35, p. 6–18, 2016.
#
# CARNEIRO, P. M.; HECKMAN, J. J. Human capital policy. IZA discussion paper, 2003.
#
# CHORNIY, A. V.; CURRIE, J.; SONCHAK, L. Does Prenatal WIC Participation Improve Child Outcomes?[S.l.], 2018.
#
# HECKMAN, J. J. et al. The rate of return to the highscope perry preschool program.Journal ofpublic Economics, Elsevier, v. 94, n. 1-2, p. 114–128, 2010.
#
# HENRICHS, J. et al. Parental family stress during pregnancy and cognitive functioning in earlychildhood: The generation r study.Early Childhood Research Quarterly, Elsevier, v. 26, n. 3, p.332–343, 2011.
#
# JUNIOR, M. V. W.; RIBEIRO, F. G.; PAESE, L. H. Z. Early childhood home-based programmesand school violence: evidence from brazil.Development in Practice, Taylor & Francis, p. 1–11,2021.
#
# NISHIMURA, F. N.; MESQUITA, A. Efeitos do programa “primeira infância melhor” sobre os casos de desnutrição infantil,.In: ANPEC - 46ºEncontro Nacional de Economia, Rio deJaneiro-RJ, 2018
#
# ***

# %% [markdown]
# # <font color='darkblue'>SISTEMA DE AVALIAÇÃO EDUCACIONAL DE PERNAMBUCO (SAEPE) </font>
# <hr style='border: 2px solid darkblue;'>

# %% [markdown]
# ### O Sistema de Avaliação Educacional de Pernambuco (SAEPE) foi criado, em 2000, com o objetivo de aferir o desempenho dos alunos da rede pública e fomentar mudanças na educação oferecida pelo estado.
#
# ### Desde 2008, o programa passou por reestruturações, com avaliações em Língua Portuguesa e Matemática ocorrendo anualmente. Os dados, referentes ao desempenho dos estudantes dos Ensinos Fundamental e Médio, são disponibilizados em uma Plataforma criada em parceria com o CAEd/UFJF.
#
# ### O seguinte código retorna a base de dados do SAEPE para as avaliações de matemática, com dados desde 2008, que utilizaremos no projeto

# %%
pd.read_csv('Dados/mat.csv', index_col=0).head()
# Out:
# C:\Users\Admin\anaconda3\lib\site-packages\IPython\core\interactiveshell.py:3444: DtypeWarning: Columns (18) have mixed types.Specify dtype option on import or set low_memory=False.
#   exec(code_obj, self.user_global_ns, self.user_ns)
#                     Rede  Código da Etapa               Etapa  Código da GRE  \
# Código da Rede
# 1               ESTADUAL                5  4ª SÉRIE/5º ANO EF            101
# 1               ESTADUAL                5  4ª SÉRIE/5º ANO EF            101
# 1               ESTADUAL                5  4ª SÉRIE/5º ANO EF            101
# 1               ESTADUAL                5  4ª SÉRIE/5º ANO EF            101
# 1               ESTADUAL                5  4ª SÉRIE/5º ANO EF            101
#
#                                           GRE  Código do Município  \
# Código da Rede
# 1               AGRESTE CENTRO NORTE(CARUARU)              2601706
# 1               AGRESTE CENTRO NORTE(CARUARU)              2601706
# ...

# %% [markdown]
# ### Para medir o efeito causal do PMCP, utilizaremos a coluna de "Proficiências Médias", como o resultado escolar.
#
# ### As colunas referentes aos municípios e anos (edição) serão a base para definirmos os grupos de tratamento e controle, com base no ano de entrada dos municípios no programa
#
# ### As colunas referentes às etapas (série escolar) e aos anos (edição) serão a base para definirmos os períodos pré e pós tratamento. Por exemplo, se formos analisar os 5º anos (que comporta crianças de 10 a 11 anos), temos que o período pré-tratamento se dá entre 2008 à 2017, sendo o ano de 2018 o primeiro período que o efeito causal pode ser capturado, pois as crianças expostas ao PMCP (nascidas a partir de 2008) estariam no 5º ano em 2018.
#
# ***
#
# ### Fonte:
#
# https://institucional.caeddigital.net/projetos/saepe-pe.html
#
# ***

# %% [markdown]
# <h1 style='color: green; font-size: 36px; font-weight: bold;'>Análise Exploratória e Descritiva dos Dados</h1>

# %% [markdown]
# **Neste Notebook foi realizada a fase de análise exploratória e descritiva das bases de dados, com base no tratamento inicial dos dados realizados no Notebook "1_Tratamento_Inicial_dos_Dados", utilizando os datasets nele gerados.**
#
# **Serão obtidas estatísticas descritivas desses conjuntos de dados, além de gráficos que nos permitam tirar algumas conclusões e insights sobre nossos datasets, comparando os grupos de tratamento e controle.**
#
# **Além disso, essa análise pode servir para identificar possíveis problemas nas nossas bases de dados, não identificados anteriormente, e que podem levar a novos procedimentos de tratamento nos dados.**

# %% [markdown]
# # <font color='red' style='font-size: 30px;'>Importando Bibliotecas</font>
# <hr style='border: 2px solid red;'>

# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt

# %% [markdown]
# # <font color='red' style='font-size: 30px;'>Importando Dados</font>
# <hr style='border: 2px solid red;'>

# %% [markdown]
# ## Definição de Cada Banco Distinto de Dados:
#
# **dados_escolas:** Dados desagregados por escolas
#
# **dados_escolas_tratamento:** Dados desagregados por escolas dentro do grupo de tratamento
#
# **dados_escolas_controle:** Dados desagregados por escolas dentro do grupo de controle
#
# **dados_municipios:** Dados agregados por municípios
#
# **dados_municipios_tratamento:** Dados agregados por municípios tratados
#
# **dados_municipios_controle:** Dados agregados por municípios não tratados

# %%
dados_escolas = pd.read_csv('Dados/dados_escolas.csv')
dados_escolas_tratamento = pd.read_csv('Dados/dados_escolas_tratamento.csv')
dados_escolas_controle = pd.read_csv('Dados/dados_escolas_controle.csv')
# Out:
# C:\Users\Admin\anaconda3\lib\site-packages\IPython\core\interactiveshell.py:3444: DtypeWarning: Columns (19) have mixed types.Specify dtype option on import or set low_memory=False.
#   exec(code_obj, self.user_global_ns, self.user_ns)

# %%
dados_municipios = pd.read_csv('Dados/dados_municipios.csv')
dados_municipios_tratamento = pd.read_csv('Dados/dados_municipios_tratamento.csv')
dados_municipios_controle = pd.read_csv('Dados/dados_municipios_controle.csv')

# %% [markdown]
# # <font color='red' style='font-size: 30px;'>Tabelas de Estatísticas Descritivas</font>
# <hr style='border: 2px solid red;'>

# %% [markdown]
# # Dados Desagregados Por Escolas:
# <hr style='border: 2px solid black;'>

# %%
dados_escolas.groupby('Edição')['Proficiência Média'].describe()
# Out:
#          count        mean        std    min     25%    50%     75%    max
# Edição
# 2008    4999.0  163.608722  21.466759   84.7  150.20  163.0  176.10  274.6
# 2009    4762.0  171.347270  20.295321   84.6  158.20  170.0  182.50  285.2
# 2010    4393.0  171.120738  22.791479  111.1  156.00  169.7  183.40  300.1
# 2011    4251.0  185.709762  24.010053  102.8  169.90  184.0  199.50  319.0
# 2012    4018.0  189.105301  23.033726  121.4  174.40  187.0  201.30  308.2
# 2013    3687.0  184.879468  25.828428   93.0  168.95  183.9  200.05  577.7
# 2014    3678.0  186.735073  24.985341   95.1  170.70  185.0  201.50  322.6
# 2015    3453.0  191.939444  25.999003  123.2  174.20  190.0  206.80  303.4
# 2016    3375.0  189.826074  26.142445  115.4  172.25  188.6  205.45  299.0
# 2017    3304.0  196.322397  25.961503   96.4  179.80  195.5  211.90  300.2
# 2018    2034.0  202.339774  23.156030  139.7  186.80  200.5  215.80  306.9

# %% [markdown]
# ## Apenas Tratamento

# %%
dados_escolas_tratamento.groupby('Edição')['Proficiência Média'].describe()
# Out:
#         count        mean        std    min      25%     50%     75%    max
# Edição
# 2008    786.0  159.349873  23.014310   84.7  144.100  158.95  173.00  251.3
# 2009    779.0  169.528241  22.593071  103.6  154.600  167.90  181.50  273.0
# 2010    704.0  169.020028  23.565261  111.8  153.075  167.00  182.20  269.8
# 2011    639.0  182.729421  24.104090  126.8  167.000  181.00  196.50  287.6
# 2012    650.0  187.686154  24.231329  123.6  170.925  185.20  202.40  272.9
# 2013    565.0  183.755929  26.671063  103.7  166.000  182.40  199.80  266.3
# 2014    563.0  183.917052  26.660766   95.1  166.200  182.30  200.20  319.5
# 2015    535.0  188.308224  27.515741  127.8  168.450  185.10  204.40  291.7
# 2016    506.0  185.754348  27.547549  116.9  166.325  184.30  202.65  278.0
# 2017    508.0  190.292323  26.954706  118.0  173.175  189.75  206.20  279.9
# 2018    238.0  200.600840  23.332663  139.7  184.725  198.45  216.05  272.2

# %% [markdown]
# ## Apenas Controle

# %%
dados_escolas_controle.groupby('Edição')['Proficiência Média'].describe()
# Out:
#          count        mean        std    min      25%     50%      75%    max
# Edição
# 2008    4176.0  164.383956  21.034886  102.4  151.200  163.70  176.500  272.2
# 2009    3950.0  171.608810  19.660316   84.6  158.925  170.40  182.600  285.2
# 2010    3658.0  171.499535  22.625536  111.1  156.900  170.30  183.700  300.1
# 2011    3579.0  186.152221  23.850041  102.8  170.400  184.60  199.850  319.0
# 2012    3363.0  189.361255  22.769304  121.4  175.050  187.20  201.100  308.2
# 2013    3088.0  185.162468  25.642679   93.0  169.600  184.30  200.200  577.7
# 2014    3084.0  187.280058  24.502416   95.3  171.600  185.70  201.800  322.6
# 2015    2892.0  192.668880  25.564390  123.2  175.600  190.55  207.025  303.4
# 2016    2847.0  190.603512  25.821031  115.4  173.100  189.40  205.850  299.0
# 2017    2772.0  197.582071  25.498068   96.4  181.200  196.50  212.600  300.2
# 2018    1780.0  202.695000  23.063098  141.0  187.175  201.00  215.825  306.9

# %% [markdown]
# # Dados Agregados Por Municípios:
# <hr style='border: 2px solid black;'>

# %%
dados_municipios.groupby('ano')['proficiencia_media_matematica'].describe()
# Out:
#       count        mean        std         min         25%         50%  \
# ano
# 2008  184.0  163.557689   9.728194  138.568182  157.613942  162.763964
# 2009  184.0  171.741575   9.777676  147.354545  164.958730  171.286548
# 2010  184.0  170.856481  11.721022  145.787500  163.819876  170.134848
# 2011  184.0  187.187723  14.578495  158.380000  178.761688  184.757210
# 2012  184.0  191.400165  13.664765  163.084000  181.671194  188.614286
# 2013  184.0  186.783085  16.073812  143.516667  176.960484  185.061275
# 2014  184.0  190.153940  16.359253  159.120000  178.868015  187.003571
# 2015  184.0  194.667115  17.513791  156.685714  182.455882  193.788205
# 2016  184.0  192.682790  17.993729  155.733333  180.961364  191.571023
# 2017  184.0  198.760726  18.276687  161.133333  186.843750  197.253846
# 2018  184.0  205.600184  18.603683  166.280000  193.462500  202.733333
#
#              75%         max
# ano
# 2008  169.108462  196.816000
# 2009  177.738942  206.516667
# ...

# %% [markdown]
# ## Apenas Tratamento:

# %%
dados_municipios_tratamento.groupby('ano')['proficiencia_media_matematica'].describe()
# Out:
#       count        mean        std         min         25%         50%  \
# ano
# 2008   24.0  160.947915   8.358300  142.901136  156.906875  159.396296
# 2009   24.0  170.081927   9.000712  155.630667  163.304241  167.785385
# 2010   24.0  168.207980   7.910161  153.233333  162.101442  169.099834
# 2011   24.0  182.099716   9.977358  161.420000  177.693434  183.581579
# 2012   24.0  187.743597  11.858292  173.552381  180.125000  185.496875
# 2013   24.0  183.044745  13.334167  164.891304  173.011250  182.254649
# 2014   24.0  185.508535  12.280387  160.945833  178.160508  183.603947
# 2015   24.0  188.795785  12.294873  171.633333  182.711954  187.563910
# 2016   24.0  186.532991  12.231220  167.417647  176.905714  182.630952
# 2017   24.0  193.498576  11.926881  170.855556  187.092059  193.234689
# 2018   24.0  201.670489  12.243209  177.890909  194.192187  199.761039
#
#              75%         max
# ano
# 2008  164.566429  177.909091
# 2009  177.029121  186.645455
# ...

# %% [markdown]
# ## Apenas Controle:

# %%
dados_municipios_controle.groupby('ano')['proficiencia_media_matematica'].describe()
# Out:
#       count        mean        std         min         25%         50%  \
# ano
# 2008  159.0  163.843575   9.821295  138.568182  158.435417  163.178947
# 2009  159.0  171.796385   9.611836  147.354545  165.245170  171.427586
# 2010  159.0  171.091291  12.022331  145.787500  163.951565  170.136364
# 2011  159.0  187.705081  14.745045  158.380000  178.908730  184.745455
# 2012  159.0  191.888956  13.888549  163.084000  183.952189  189.325000
# 2013  159.0  187.157499  16.289084  143.516667  177.925000  186.311111
# 2014  159.0  190.596249  16.547483  159.120000  179.449437  187.515385
# 2015  159.0  195.364992  17.940406  156.685714  182.342857  194.879024
# 2016  159.0  193.435692  18.492987  155.733333  181.694361  192.132258
# 2017  159.0  199.389231  18.899280  161.133333  186.737500  197.813636
# 2018  159.0  205.957183  19.173965  166.280000  193.450000  204.416667
#
#              75%         max
# ano
# 2008  169.308173  196.816000
# 2009  177.688010  206.516667
# ...

# %% [markdown]
# # <font color='red' style='font-size: 30px;'>Evolução Anual das Proficiências Médias</font>
# <hr style='border: 2px solid red;'>

# %%
ax = sns.lineplot(data=dados_escolas_tratamento.groupby('Edição')['Proficiência Média'].mean())
ax = sns.lineplot(data=dados_escolas_controle.groupby('Edição')['Proficiência Média'].mean())
ax.figure.set_size_inches(12, 6)
plt.axvline(2017, linestyle='--')
ax.set_xlabel('Ano', fontsize=12)
ax.set_ylabel('Proficiência Média', fontsize=12)
ax.set_title('Evolução Anual das Proficiências Médias', fontsize=16)
plt.figlegend(labels=["Escolas Tratadas","Escolas Não Tratadas"], loc = (0.1,0.8))

# %% [markdown]
# **A linha tracejada azul divide os períodos pré e pós tratamento**

# %% [markdown]
# ### <font color='darkblue'> Premilinarmente, podemos notar que o grupo de tratamento possui um patamar de notas inferior ao grupo de controle desde o primeiro ano de avaliação do SAEPE (o que pode, inclusive, indicar uma boa focalização do programa).</font>
#
# ### <font color='darkblue'>O ano de 2018 marca uma aproximação entre as duas curvas, que vinham seguindo trajetórias aparentemente paralelas, porém com um gap maior, o que pode ser um indício preliminar de efeito do PMCP no desempenho escolar.</font>

# %% [markdown]
# # <font color='red' style='font-size: 30px;'>Variação Anual das Proficiências Médias</font>
# <hr style='border: 2px solid red;'>

# %%
dados_escolas_tratamento.groupby('Edição')['Proficiência Média'].mean().diff()
# Out:
# Edição
# 2008          NaN
# 2009    10.178369
# 2010    -0.508213
# 2011    13.709393
# 2012     4.956733
# 2013    -3.930225
# 2014     0.161122
# 2015     4.391173
# 2016    -2.553876
# 2017     4.537975
# 2018    10.308518
# Name: Proficiência Média, dtype: float64

# %%
dados_escolas_controle.groupby('Edição')['Proficiência Média'].mean().diff()
# Out:
# Edição
# 2008          NaN
# 2009     7.224854
# 2010    -0.109275
# 2011    14.652686
# 2012     3.209034
# 2013    -4.198787
# 2014     2.117591
# 2015     5.388821
# 2016    -2.065367
# 2017     6.978558
# 2018     5.112929
# Name: Proficiência Média, dtype: float64

# %%
ax = sns.lineplot(data=dados_escolas_tratamento.groupby('Edição')['Proficiência Média'].mean().diff())
ax = sns.lineplot(data=dados_escolas_controle.groupby('Edição')['Proficiência Média'].mean().diff())
ax.figure.set_size_inches(12, 6)
plt.axvline(2017, linestyle='--')
ax.set_xlabel('Ano', fontsize=12)
ax.set_ylabel('Variação da Proficiências Média', fontsize=12)
ax.set_title('Variação Anual da Proficiência Média', fontsize=16)
plt.figlegend(labels=["Escolas Tratadas","Escolas Não Tratadas"], loc = (0.08,0.84))

# %% [markdown]
# ### <font color='darkblue'>Aqui nós temos uma evidência mais poderosa de efeito do programa. Ambos os grupos seguiam a mesma trajetória de variação da proficiência média em todos os anos no período pré-tratamento.</font>
#
# ### <font color='darkblue'>O ano de 2018, que revela a taxa de variação com o efeito do PMCP, é justamente o único ano de toda a série temporal em que há uma inflexão nessa tendência, com a média das escolas não tratadas crescendo em um ritmo mais desacelerado em comparaçao ao grupo de tratamento, cuja variação praticamente seguiu a tendêndia do período anterior.</font>

# %% [markdown]
# ### <font color='red'>Para esta fase da análise, não utilizaremos os dados agregados por municípios, pois, na prática, estaríamos calculando a média das médias das escolas, ao obtermos a média dos municípios de tratamento e controle, o que pode ser problemático.</font>
#
# ### <font color='red'>Faz mais sentido simplesmente utilizar os dados desagregados por escolas e tirar a média aritmética das escolas tratadas e não tratadas.</font>
#
# ### <font color='red'>Esses dados serão mais importantes futuramente, ao se estimar o modelo de Controle Sintético.</font>

# %% [markdown]
# # <font color='red' style='font-size: 30px;'>Distribuição de Frequências</font>
# <hr style='border: 2px solid red;'>

# %%
fig, axes = plt.subplots(2, 2, figsize=(18, 10))

fig.suptitle('Evolução da Distribuição das Proficiências Médias ao Longo dos Anos', fontsize=18)
fig.patch.set_facecolor('xkcd:light grey')


sns.kdeplot(ax=axes[0, 0], 
            x=dados_escolas_tratamento.groupby('Edição').get_group(2010)['Proficiência Média'])
sns.kdeplot(ax=axes[0, 0], 
            x=dados_escolas_controle.groupby('Edição').get_group(2010)['Proficiência Média'])

axes[0,0].set_title(2010, fontsize=16)
axes[0,0].set_xlabel('Proficiência Média', fontsize=12)
axes[0,0].set_ylabel('Frequência', fontsize=12)
axes[0,0].set_xlim(50,350)
axes[0,0].set_ylim(0,0.025)


sns.kdeplot(ax=axes[0, 1], 
            x=dados_escolas_tratamento.groupby('Edição').get_group(2014)['Proficiência Média'])
sns.kdeplot(ax=axes[0, 1], 
            x=dados_escolas_controle.groupby('Edição').get_group(2014)['Proficiência Média'])

axes[0,1].set_title(2014, fontsize=16)
axes[0,1].set_xlabel('Proficiência Média', fontsize=12)
axes[0,1].set_ylabel('Frequência', fontsize=12)
axes[0,1].set_xlim(50,350)
axes[0,1].set_ylim(0,0.025)


sns.kdeplot(ax=axes[1, 0], 
            x=dados_escolas_tratamento.groupby('Edição').get_group(2016)['Proficiência Média'])
sns.kdeplot(ax=axes[1, 0], 
            x=dados_escolas_controle.groupby('Edição').get_group(2016)['Proficiência Média'])

axes[1,0].set_title(2016, fontsize=16)
axes[1,0].set_xlabel('Proficiência Média', fontsize=12)
axes[1,0].set_ylabel('Frequência', fontsize=12)
axes[1,0].set_xlim(50,350)
axes[1,0].set_ylim(0,0.025)


sns.kdeplot(ax=axes[1, 1], 
            x=dados_escolas_tratamento.groupby('Edição').get_group(2018)['Proficiência Média'])
sns.kdeplot(ax=axes[1, 1], 
            x=dados_escolas_controle.groupby('Edição').get_group(2018)['Proficiência Média'])

axes[1,1].set_title(2018, fontsize=16)
axes[1,1].set_xlabel('Proficiência Média', fontsize=12)
axes[1,1].set_ylabel('Frequência', fontsize=12)
axes[1,1].set_xlim(50,350)
axes[1,1].set_ylim(0,0.025)

plt.figlegend(labels=["Escolas Tratadas","Escolas Não Tratadas"], loc = (0.445, 0.425), fontsize=12)
fig.tight_layout(pad=3.0)

# %% [markdown]
# ### <font color='darkblue'> Novamente é visível o patamar inferior das proficiências do grupo de tratamento em comparação ao grupo de controle desde o primeiro ano indicado.</font>
#
# ### <font color='darkblue'>Assim como no gráfico de evolução das proficiências médias ao longo dos anos, é perceptível uma certa aproximação do comportamentodo grupo de tratamento ao comportamento do grupo de controle no ano de 2018.</font>
#
# ### <font color='darkblue'>Essa aproximação é mais perceptível na cauda inferior, que denota as menores notas, e pode ser uma evidência de eficácia do programa, na medida que ele conseguiu compensar um <font color='red'>"Culling Effect".</font> </font>
#
# ***
# ### <font color='darkred'>Definição de "Culling Effect":</font> <font color='red'>  Nessa literatura, esse efeito surge quando se tenta avaliar resultados futuros oriundos de algum efeito exógeno que esteja associado com redução de mortalidade (que é o caso do PMCP). Esse efeito aparece como uma "piora" dos resultados futuros, pois essa população excedente, por mais que tenha sobrevivido, tende a ser mais vulnerável, apresentando resultados futuros ruins de modo a reduzir a média da população total analisada.</font>
#
# ### <font color='darkblue'>Fonte:</font>
# ALMOND, Douglas; CURRIE, Janet; DUQUE, Valentina. Childhood circumstances and adult outcomes: Act II. Journal of Economic Literature, v. 56, n. 4, p. 1360-1446, 2018.
#
# ***
#
# ### <font color='darkblue'>Deste modo, seria razoável supor que o PMCP tenha sido não só capaz de reduzir a mortalidade, como também de elevar as notas dessa população mais vulnerável.</font>

# %% [markdown]
# # <font color='red' style='font-size: 30px;'>Investigando Outliers</font>
# <hr style='border: 2px solid red;'>

# %%
ax = sns.boxplot(data = dados_escolas, x='Proficiência Média', y='Edição', orient='h')
ax.figure.set_size_inches(20, 16)

# %%
dados_escolas.query('`Proficiência Média` > 500')
# Out:
#        Unnamed: 0  Código da Rede       Rede  Código da Etapa  \
# 23390       49392               2  MUNICIPAL                5
#
#                       Etapa  Código da GRE  \
# 23390  4ª SÉRIE / 5º ANO EF            104
#
#                                        GRE  Código do Município Município  \
# 23390  MATA CENTRO(VITORIA DE SANTO ANTAO)              2601904  BEZERROS
#
#        Código da Escola  ... Proficiência Média  Desvio Padrão  \
# 23390          26051370  ...              577.7           32,6
#
#        Padrão de Desempenho Elementar I Elementar II Básico Desejável  \
# 23390             Desejável         0,0          0,0    0,0     100,0
#
#       Estudantes Previstos Estudantes Efetivos Percentual de Participação
# 23390                   24                   2                        8,3
#
# [1 rows x 22 columns]

# %% [markdown]
# ### **Ao analisar esse outlier podemos levantar a possibilidade de termos no nosso data frame um problema relacionado com o tamanho da escola (poucos alunos fazendo o exame) e/ou com o percentual de participação na prova**

# %%
dados_escolas['Estudantes Efetivos'].describe()
# Out:
# count    41954.000000
# mean        29.571626
# std         31.077261
# min          1.000000
# 25%          8.000000
# 50%         17.000000
# 75%         42.000000
# max        284.000000
# Name: Estudantes Efetivos, dtype: float64

# %%
print('Todas as observações:', dados_escolas.shape[0])
print('Observações de escolas com menos de 10 alunos:', dados_escolas.query('`Estudantes Efetivos` < 10').shape[0])
# Out:
# Todas as observações: 41954
# Observações de escolas com menos de 10 alunos: 13482

# %%
dados_escolas.head()
# Out:
#    Unnamed: 0  Código da Rede      Rede  Código da Etapa               Etapa  \
# 0           0               1  ESTADUAL                5  4ª SÉRIE/5º ANO EF
# 1           1               1  ESTADUAL                5  4ª SÉRIE/5º ANO EF
# 2           2               1  ESTADUAL                5  4ª SÉRIE/5º ANO EF
# 3           3               1  ESTADUAL                5  4ª SÉRIE/5º ANO EF
# 4           4               1  ESTADUAL                5  4ª SÉRIE/5º ANO EF
#
#    Código da GRE                            GRE  Código do Município  \
# 0            101  AGRESTE CENTRO NORTE(CARUARU)              2601706
# 1            101  AGRESTE CENTRO NORTE(CARUARU)              2601706
# 2            101  AGRESTE CENTRO NORTE(CARUARU)              2601706
# 3            101  AGRESTE CENTRO NORTE(CARUARU)              2601706
# 4            101  AGRESTE CENTRO NORTE(CARUARU)              2601706
#
#      Município  Código da Escola  ... Proficiência Média  Desvio Padrão  \
# ...

# %% [markdown]
# ### <font color='darkblue'>Podemos notar haver uma grande parcela de escolas "pequenas" (com poucos alunos) no nosso data frame, portanto, simplesmente tentar filtrar outliers com base no tamanho da escola pode ser problemático.</font>
#
# ### <font color='darkblue'>Uma abordagem possível para evitar fortes pertubações nos dados pode ser, por exemplo, ponderar a nota da escola por alunos ao lidarmos com os dados em níveis mais agregados.</font>
#
# ### <font color='darkblue'>Alternativamente ou conjuntamente com a abordagem sugerida acima, podemos considerar remover escolas com um baixo percentual de participação no exame, mas note que o ano de 2008 não contém informações sobre esta coluna, portanto, estaríamos sacrificando um ano inteiro no nosso Data Frame.</font>

# %% [markdown]
# # Comparando Controle e Tratamento

# %%
ax = sns.boxplot(data = dados_escolas_tratamento, x='Proficiência Média', y='Edição', orient='h')
ax.figure.set_size_inches(20, 16)

# %%
ax = sns.boxplot(data = dados_escolas_controle.query('`Proficiência Média` < 500'), 
                 x='Proficiência Média', y='Edição', orient='h')
ax.figure.set_size_inches(20, 16)

# %%
print('Tamanho das observações do grupo de tratamento: {}'.format(dados_escolas_tratamento.shape[0]))
print('Tamanho das observações do grupo de controle: {}'.format(dados_escolas_controle.shape[0]))
proporção_grupos = dados_escolas_controle.shape[0]/dados_escolas_tratamento.shape[0]
print('O grupo de controle é {} vezes maior que o grupo de tratamento'.format(round(proporção_grupos, 2)))
# Out:
# Tamanho das observações do grupo de tratamento: 6473
# Tamanho das observações do grupo de controle: 35189
# O grupo de controle é 5.44 vezes maior que o grupo de tratamento

# %% [markdown]
# ### <font color='darkblue'>A princípio, pode-se inferir que o grupo de controle sofre mais com a ocorrência de outliers, o que poderia gerar um grande problema para a nossa análise. Entretanto, ao comparar o tamanho dos grupos, percebemos que esse problema está muito possivelmente relacionado com o distinto número de observações em cada grupo, que é bem maior no grupo de controle (mais de 5 vezes).</font>
#
# ### <font color='darkblue'>Deste modo, a princípio, não veremos os outliers como um grande problema na nossa base de dados, lidando apenas com os casos mais extremos.</font>
#
# ### <font color='darkblue'>Além do mais, temos que o grupo de tratamento foi selecionado a partir das regiões com maiores índices de mortalidade infantil. É de se esperar que essas regiões realmente tenham menos ocorrência de outliers à direita em comparação ao grupo de controle que incorpora escolas de regiões com distintas condições socioeconômicas, de modo a apresentar uma concentração muito alta de outliers à direita.</font>
#
# ### <font color='darkblue'>O simples ato de agregar as proficiências médias por municípios ou outro nível regional pode corrigir esse problema, tornando talvez desnecessário ponderar por número de alunos ou excluir escolas com baixo índice de participação</font>

# %% [markdown]
# # Nas seções seguintes, serão aplicadas essas transformações sugeridas nos dados e compararemos com nossa análise anterior:

# %% [markdown]
# # <font color='red' style='font-size: 30px;'>Proficiência Média Ponderada Por Alunos</font>
# <hr style='border: 2px solid red;'>

# %%
grupo_escolas_ano = dados_escolas_tratamento.groupby('Edição')
proficiencia_media_ponderada_tratamento = []

for ano in grupo_escolas_ano.groups.keys():
      proficiencia_media_ponderada_tratamento.append(np.average(grupo_escolas_ano.get_group(ano)['Proficiência Média'], 
                                              weights = grupo_escolas_ano.get_group(ano)['Estudantes Efetivos']))
                                              
proficiencia_media_ponderada_tratamento = pd.Series(proficiencia_media_ponderada_tratamento, 
                                                  index=dados_escolas['Edição'].unique())
proficiencia_media_ponderada_tratamento.index.name = 'Ano'
proficiencia_media_ponderada_tratamento
# Out:
# Ano
# 2008    161.954421
# 2009    171.966781
# 2010    171.803749
# 2011    184.391720
# 2012    188.400904
# 2013    186.753792
# 2014    188.229179
# 2015    190.738995
# 2016    188.968992
# 2017    193.389149
# 2018    201.115450
# dtype: float64

# %%
grupo_escolas_ano = dados_escolas_controle.groupby('Edição')
proficiencia_media_ponderada_controle= []

for ano in grupo_escolas_ano.groups.keys():
      proficiencia_media_ponderada_controle.append(np.average(grupo_escolas_ano.get_group(ano)['Proficiência Média'], 
                                              weights = grupo_escolas_ano.get_group(ano)['Estudantes Efetivos']))
                                              
proficiencia_media_ponderada_controle = pd.Series(proficiencia_media_ponderada_controle, 
                                                  index=dados_escolas['Edição'].unique())
proficiencia_media_ponderada_controle.index.name = 'Ano'
proficiencia_media_ponderada_controle
# Out:
# Ano
# 2008    166.345346
# 2009    173.409901
# 2010    172.939759
# 2011    187.239024
# 2012    189.402489
# 2013    187.778711
# 2014    189.242514
# 2015    193.446797
# 2016    191.910900
# 2017    198.552921
# 2018    202.494436
# dtype: float64

# %%
ax = sns.lineplot(data=proficiencia_media_ponderada_tratamento)
ax = sns.lineplot(data=proficiencia_media_ponderada_controle)
ax.figure.set_size_inches(12, 6)
plt.axvline(2017, linestyle='--')
ax.set_xlabel('Ano', fontsize=12)
ax.set_ylabel('Proficiência Média', fontsize=12)
ax.set_title('Evolução Anual das Proficiências Médias Ponderadas por Alunos', fontsize=16)
plt.figlegend(labels=["Escolas Tratadas","Escolas Não Tratadas"], loc = (0.1,0.8))

# %%
ax = sns.lineplot(data=proficiencia_media_ponderada_tratamento.diff())
ax = sns.lineplot(data=proficiencia_media_ponderada_controle.diff())
ax.figure.set_size_inches(12, 6)
plt.axvline(2017, linestyle='--')
ax.set_xlabel('Ano', fontsize=12)
ax.set_ylabel('Variação Anual da Proficiência Média Ponderada (%)', fontsize=12)
ax.set_title('Variação Anual da Proficiência Média - Ponderada por Alunos', fontsize=16)
plt.figlegend(labels=["Escolas Tratadas","Escolas Não Tratadas"], loc = (0.074,0.84))

# %% [markdown]
# ## <font color='black'>Comparando com o Resultado Anterior:</font>
# <hr style='border: 2px solid black;'>

# %%
ax = plt.figure(figsize=(18, 10))
ax.patch.set_facecolor('xkcd:light grey')
ax1 = ax.add_subplot(2,1,1)
ax2 = ax.add_subplot(2,1,2)

sns.lineplot(ax=ax1, data=dados_escolas_tratamento.groupby('Edição')['Proficiência Média'].mean(), 
             label = "Municípios Tratados")
sns.lineplot(ax=ax1, data=dados_escolas_controle.groupby('Edição')['Proficiência Média'].mean(), 
             label = "Municípios Controle")
plt.axvline(2017, linestyle='--')
ax1.set_title('Proficiência Média em Matemática')
ax1.axvline(2017, linestyle='--')

sns.lineplot(ax=ax2, data=proficiencia_media_ponderada_tratamento, label = "Municípios Tratados")
sns.lineplot(ax=ax2, data=proficiencia_media_ponderada_controle, label = "Municípios de Controle")
ax2.axvline(2017, linestyle='--')
ax2.set_title('Proficiência Média Ponderada em Matemática')
# Out:
# Text(0.5, 1.0, 'Proficiência Média Ponderada em Matemática')

# %%
ax = plt.figure(figsize=(18, 10))
ax.patch.set_facecolor('xkcd:light grey')
ax1 = ax.add_subplot(2,1,1)
ax2 = ax.add_subplot(2,1,2)

sns.lineplot(ax=ax1, data=dados_escolas_tratamento.groupby('Edição')['Proficiência Média'].mean().diff(),
            label = "Média das Escolas Tratadas")
sns.lineplot(ax=ax1, data=dados_escolas_controle.groupby('Edição')['Proficiência Média'].mean().diff(),
            label = "Média das Escolas Não Tratadas")
ax1.axvline(2017, linestyle='--')
ax1.set_title('Proficiência Média em Matemática')


sns.lineplot(ax=ax2, data=proficiencia_media_ponderada_tratamento.diff(),
            label = "Média das Escolas Tratadas")
sns.lineplot(ax=ax2, data=proficiencia_media_ponderada_controle.diff(),
            label = "Média das Escolas Não Tratadas")
ax2.axvline(2017, linestyle='--')
ax2.set_title('Proficiência Média Ponderada em Matemática')
# Out:
# Text(0.5, 1.0, 'Proficiência Média Ponderada em Matemática')

# %% [markdown]
# ### <font color='darkblue'>Podemos notar que não há grandes diferenças nas trajetórias das linhas em ambos os gráficos quando comparamos a média aritmética simples das escolas às médias ponderadas. </font>
#
# ### <font color='darkblue'> Quanto ao gráfico de evolução das médias, podemos notar que para o caso das médias ponderadas, o gap entre o grupo de tratados e de controle parece ser menor. </font>
#
# ### <font color='darkblue'> Quanto ao gráfico de variação das médias, as diferenças são menos perceptíveis.</font>
#
#
# ###  <font color='darkblue'> Podemos concluir, com base nos gráficos, que utilizar média ponderada por aluno ao invés da média simples das escolas não produz uma divergência muito grande, com as curvas seguindo a mesma trajetória. Mantemos nossa análise anterior como válida.</font>

# %% [markdown]
# # <font color='red' style='font-size: 30px;'>Excluindo Escolas com Baixo Percentual de Participação</font>
# <hr style='border: 2px solid red;'>

# %% [markdown]
# ## <font color='black'>Filtrando os Dados:</font>
# <hr style='border: 2px solid black;'>

# %%
percentual_participacao = []
dados_escolas_tratamento_filtrado_por_participacao = dados_escolas_tratamento

for item in dados_escolas_tratamento['Percentual de Participação']:
    percentual_participacao.append(item.replace(',','.').replace('-', ''))

dados_escolas_tratamento_filtrado_por_participacao['Percentual de Participação'] = percentual_participacao
dados_escolas_tratamento_filtrado_por_participacao['Percentual de Participação'] = pd.to_numeric(dados_escolas_tratamento_filtrado_por_participacao['Percentual de Participação'], 
                                                                       errors='coerce')
dados_escolas_tratamento_filtrado_por_participacao['Percentual de Participação'] = dados_escolas_tratamento_filtrado_por_participacao['Percentual de Participação'].astype(float)

# %%
dados_escolas_tratamento_filtrado_por_participacao.dropna(subset = ['Percentual de Participação'], inplace = True)

# %%
dados_escolas_tratamento_filtrado_por_participacao = dados_escolas_tratamento_filtrado_por_participacao.query('`Percentual de Participação` > 50')

# %%
percentual_participacao = []
dados_escolas_controle_filtrado_por_participacao = dados_escolas_controle

for item in dados_escolas_controle['Percentual de Participação']:
    percentual_participacao.append(item.replace(',','.').replace('-', ''))

dados_escolas_controle_filtrado_por_participacao['Percentual de Participação'] = percentual_participacao
dados_escolas_controle_filtrado_por_participacao['Percentual de Participação'] = pd.to_numeric(dados_escolas_controle_filtrado_por_participacao['Percentual de Participação'], 
                                                                       errors='coerce')
dados_escolas_controle_filtrado_por_participacao['Percentual de Participação'] = dados_escolas_controle_filtrado_por_participacao['Percentual de Participação'].astype(float)

# %%
dados_escolas_controle_filtrado_por_participacao.dropna(subset = ['Percentual de Participação'], inplace = True)

# %%
dados_escolas_controle_filtrado_por_participacao = dados_escolas_controle_filtrado_por_participacao.query('`Percentual de Participação` > 50')

# %% [markdown]
# ## <font color='black'>Comparando Com os Resultados Anteriores:</font>
# <hr style='border: 2px solid black;'>

# %%
ax = plt.figure(figsize=(18, 10))
ax.patch.set_facecolor('xkcd:light grey')
ax1 = ax.add_subplot(2,1,1)
ax2 = ax.add_subplot(2,1,2)

sns.lineplot(ax=ax1, data=dados_escolas_tratamento.groupby('Edição')['Proficiência Média'].mean(), 
             label = "Municípios Tratados")
sns.lineplot(ax=ax1, data=dados_escolas_controle.groupby('Edição')['Proficiência Média'].mean(), 
             label = "Municípios Controle")
ax1.set_title('Proficiência Média em Matemática')
ax1.axvline(2017, linestyle='--')

sns.lineplot(ax=ax2, data=dados_escolas_tratamento_filtrado_por_participacao.groupby('Edição')['Proficiência Média'].mean(), 
             label = "Municípios Tratados")
sns.lineplot(ax=ax2, data=dados_escolas_controle_filtrado_por_participacao.groupby('Edição')['Proficiência Média'].mean(), 
             label = "Municípios de Controle")
ax2.axvline(2017, linestyle='--')
ax2.set_title('Proficiência Média em Mátemática - Filtrada por Participação')
# Out:
# Text(0.5, 1.0, 'Proficiência Média em Mátemática - Filtrada por Participação')

# %%
ax = plt.figure(figsize=(18, 10))
ax.patch.set_facecolor('xkcd:light grey')
ax1 = ax.add_subplot(2,1,1)
ax2 = ax.add_subplot(2,1,2)

sns.lineplot(ax=ax1, data=dados_escolas_tratamento.groupby('Edição')['Proficiência Média'].mean().diff(), 
             label = "Média das Escolas Tratadas")
sns.lineplot(ax=ax1, data=dados_escolas_controle.groupby('Edição')['Proficiência Média'].mean().diff(), 
             label = "Média das Escolas Não Tratadas")
ax1.set_title('Proficiência Média em Matemática')
ax1.axvline(2017, linestyle='--')

sns.lineplot(ax=ax2, data=dados_escolas_tratamento_filtrado_por_participacao.groupby('Edição')['Proficiência Média'].mean().diff(),
            label = "Média das Escolas Tratadas")
sns.lineplot(ax=ax2, data=dados_escolas_controle_filtrado_por_participacao.groupby('Edição')['Proficiência Média'].mean().diff(),
            label = "Média das Escolas Não Tratadas")
ax2.axvline(2017, linestyle='--')
ax2.set_title('Proficiência Média em Matemática - Filtrada por Participação')
# Out:
# Text(0.5, 1.0, 'Proficiência Média em Matemática - Filtrada por Participação')

# %% [markdown]
# ### <font color='darkblue'>Podemos notar, novamente, que não há grandes diferenças nas trajetórias das linhas em ambos os gráficos ao comparar a média simples das escolas às médias filtradas por escolas com índice de participação no SAEPE menor que 50%. Nesse caso tanto as trajetórias das curvas quanto os gaps são bem similiares.</font>
#
# ### <font color='darkblue'> Quanto ao gráfico de evolução das médias, podemos notar diferenças suaves e quase imperceptíveis. </font>
#
# ### <font color='darkblue'> Quanto ao gráfico de variação das médias, as diferenças também são pequenas.</font>
#
#
# ###  <font color='darkblue'> Podemos concluir, com base nos gráficos, que remover as escolas com baixo percentual de participação no SAEPE a cada ano produz muita variações quase imperceptíveis nos nossos dados, com as curvas seguindo a mesma trajetória e com gaps muito parecidos. Mantemos novamente nossa análise anterior como válida.</font>
